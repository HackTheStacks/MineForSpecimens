# %%
import os
import sys
import json
import csv
import pandas as pd

try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
    
from functions import *

# %%
def findSpecieInPDF(itemId):
    #download PDF
    
    os.system('wget --no-check-certificate https://digitallibrary.amnh.org/rest/bitstreams/'+str(itemId)+'/retrieve -O ' + itemId + '.pdf')
    #apply Rons functions
    
    #remove pdf
    os.system('rm '+ itemId + '.pdf')
    
    #apply Bens function
    
    return listOfSpecies

# %%
#id2016 = getIdsFromPeriod(2016)
[getMetadata(i) for i in getIdsFromPeriod(2016)]
# Out:
# [{'authors': [u'Zazula, Grant D.',
#    u'MacPhee, R. D. E.',
#    u'Hall, Elizabeth (Paleontologist)',
#    u'Hewitson, Susan.'],
#   u'dc.date.available': u'2016-10-19T22:25:33Z',
#   u'dc.date.issued': u'2016-10-19',
#   u'dc.description': u'45 pages : illustrations (chiefly color), map ; 26 cm.',
# ...
