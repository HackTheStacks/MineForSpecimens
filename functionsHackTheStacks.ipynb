# %%
import os
import sys
import json
import csv
import pandas as pd

try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
    
from functions import *

# %%
def findSpecieInPDF(itemId):
    #download PDF
    
    os.system('wget --no-check-certificate https://digitallibrary.amnh.org/rest/bitstreams/'+str(itemId)+'/retrieve -O ' + itemId + '.pdf')
    #apply Rons functions
    
    #remove pdf
    os.system('rm '+ itemId + '.pdf')
    
    #apply Bens function
    
    return listOfSpecies

# %%
id2016 = getIdsFromPeriod(2016)
[getMetadata(i)['subjects'] for i in getIdsFromPeriod(2016)]
# Out:
# [[u'Camelops hesternus.', u'Camelidae, Fossil.', u'Alaska.', u'Yukon.'],
#  [u'Artiodactyla.',
#   u'Middle ear.',
#   u'Skull base.',
#   u'Cetacea.',
#   u'Aquatic mammals.',
#   u'Underwater acoustics.',
#   u'Auditory pathways.',
#   u'Ungulates.',
#   u'Phylogeny.'],
#  [u'Zhenia xiai.',
#   u'Zhenia.',
#   u'Eremochaetidae.',
#   u'Archisargoidea.',
#   u'Diptera, Fossil.',
#   u'Amber fossils.',
#   u'Brachycera.',
#   u'Phylogeny.',
#   u'Paleoentomology.',
#   u'Hukawng Valley (Burma)',
#   u'Burma.'],
#  [u'Diptera, Fossil.',
#   u'Amber fossils.',
#   u'Brachycera.',
#   u'Phylogeny.',
#   u'Paleoentomology.',
#   u'Hukawng Valley (Burma)',
#   u'Burma.'],
#  [u'Osmiini.', u'Larvae.', u'Nests.', u'Bees.'],
#  [u'Megachile.', u'Larvae.', u'Bees.', u'Variation (Biology)'],
#  [u'Pandinus.', u'Scorpionidae.', u'Scorpions.', u'Africa, East.'],
#  [u'Calciavis grandei.',
#   u'Lithornithidae.',
#   u'Ratites, Fossil.',
#   u'Ratites.',
#   u'Phylogeny.',
#   u'Fossil Butte National Monument (Wyo.)',
#   u'Green River Formation.',
#   u'Wyoming.'],
#  [u'Burmisotoma spinulifera.',
#   u'Protoisotoma autrigoniensis.',
#   u'Proisotoma communis.',
#   u'Isotomidae.',
#   u'Collembola.',
#   u'Insects, Fossil.',
#   u'Amber fossils.',
#   u'Spain.'],
#  [u'Calciavis grandei.',
#   u'Lithornithidae.',
#   u'Ratites, Fossil.',
#   u'Ratites.',
#   u'Phylogeny.',
#   u'Fossil Butte National Monument (Wyo.)',
#   u'Green River Formation.',
#   u'Wyoming.'],
#  [u'Maaykuyak.',
#   u'Syntropis.',
#   u'Vizcaino (Scorpion)',
#   u'Syntropis williamsi.',
#   u'Syntropinae.',
#   u'Vaejovidae.',
#   u'Scorpions.',
#   u'Southwest, New.',
#   u'Mexico, North.'],
#  [u'Maaykuyak.',
#   u'Syntropis.',
#   u'Vizcaino (Scorpion)',
#   u'Syntropis williamsi.',
#   u'Syntropinae.',
#   u'Vaejovidae.',
#   u'Scorpions.',
#   u'Southwest, New.',
#   u'Mexico, North.'],
#  [u'Huayqueriana.',
#   u'Skull.',
#   u'Macraucheniidae.',
#   u'Mendoza (Argentina : Province)',
#   u'Argentina.'],
#  [u'Felisacus.',
#   u'Miridae.',
#   u'Ferns.',
#   u'Host plants.',
#   u'Insect-plant relationships.',
#   u'Phylogeny.',
#   u'Indo-Pacific Region.'],
#  [u'Huayqueriana.',
#   u'Skull.',
#   u'Macraucheniidae.',
#   u'Mendoza (Argentina : Province)',
#   u'Argentina.'],
#  [u'Felisacus.',
#   u'Miridae.',
#   u'Ferns.',
#   u'Host plants.',
#   u'Insect-plant relationships.',
#   u'Phylogeny.',
#   u'Indo-Pacific Region.'],
#  [u'Eufriesea surinamensis -- Larvae.',
#   u'Eufriesea mussitans -- Larvae.',
#   u'Euglossa cordata -- Larvae.',
#   u'Eulaema polychroma -- Larvae.',
#   u'Euglossini -- Larvae.',
#   u'Bees -- Larvae.'],
#  [u'Pulvillophylus cuneomaculatus.',
#   u'Pulvillophylus ecdeiocoleae.',
#   u'Pulvillophylus.',
#   u'Ecdeiocolea monostachya.',
#   u'Miridae.',
#   u'Host plants.',
#   u'Insect-plant relationships.',
#   u'Western Australia.',
#   u'Australia.'],
#  [u'Drosophila bromeliae.',
#   u'Drosophila.',
#   u'Central America.',
#   u'Caribbean Area.',
#   u'Andes Region.'],
#  [u'Sciophanes.', u'Marmosops.', u'Marsupials.', u'Latin America.'],
#  [u'Sciophanes.', u'Marmosops.', u'Marsupials.', u'Latin America.'],
#  [u'Nesolinoceras.',
#   u'Nesolinoceras ornatipennis.',
#   u'Nesolinoceras laluzbrillante.',
#   u'Ichneumonidae.',
#   u'Bahamas.',
#   u'Cayman Islands.',
#   u'Dominican Republic.',
#   u'West Indies.'],
#  [u'Aegyptonycteridae.',
#   u'Aegyptonycteris.',
#   u'Aegyptonycteris knightae.',
#   u'Bats, Fossil.',
#   u'Nomenclature.',
#   u'Fayy\u016bm (Egypt : Province)',
#   u'Birket Qarun Formation (Egypt)',
#   u'Egypt.'],
#  [u'Cremnorrhinina.',
#   u'Miridae.',
#   u'Host plants.',
#   u'Insect-plant relationships.',
#   u'Australia.'],
#  [u'Cremnorrhinina.',
#   u'Miridae.',
#   u'Host plants.',
#   u'Insect-plant relationships.',
#   u'Australia.'],
#  [u'Ectrichodiinae.', u'Assassin bugs.', u'Endemic animals.', u'Madagascar.'],
#  [u'Ectrichodiinae.', u'Assassin bugs.', u'Endemic animals.', u'Madagascar.'],
#  [u'Hesperapis rhodocerata.',
#   u'Hesperapis larreae.',
#   u'Hesperapis.',
#   u'Bees.',
#   u'Nests.',
#   u'Larvae.',
#   u'Behavior.',
#   u'New Mexico.'],
#  [u'Hesperapis rhodocerata.',
#   u'Hesperapis larreae.',
#   u'Hesperapis.',
#   u'Bees.',
#   u'Nests.',
#   u'Larvae.',
#   u'Behavior.',
#   u'New Mexico.'],
#  [u'Holopsenella primotica.',
#   u'Holopsenella.',
#   u'Holopsenellinae.',
#   u'Wasps, Fossil.',
#   u'Amber fossils.',
#   u'Bethylidae.',
#   u'Zophepyris alavaensis.',
#   u'Zophepyris.',
#   u'Archaepyris.',
#   u'Lebanon.',
#   u'Spain, Northern.'],
#  [u'Synemporion.',
#   u'Synemporion keana.',
#   u'Bats, Fossil.',
#   u'Vespertilionidae.',
#   u'Extinct mammals.',
#   u'Endemic animals.',
#   u'Hawaii.'],
#  [u'Ruby Pipeline Project.',
#   u'Paleo-Indians.',
#   u'Land settlement patterns.',
#   u'Shoshoni Indians.',
#   u'Northern Paiute Indians.',
#   u'Numic Indians.',
#   u'Excavations (Archaeology)',
#   u'Antiquities, Prehistoric.',
#   u'Ruby Mountains Region (Nev.)',
#   u'Nevada.'],
#  [u'Tropidurus sertanejo.',
#   u'Lava lizards.',
#   u'Tropiduridae.',
#   u'Phylogeny.',
#   u'Caatinga reptiles.',
#   u'Bahia (Brazil : State)',
#   u'Brazil.',
#   u'South America.'],
#  [u'Tropidurus lagunablanca.',
#   u'Tropidurus tarara.',
#   u'Tropidurus teyumirim.',
#   u'Lava lizards.',
#   u'Tropiduridae.',
#   u'Paraguay, Eastern.'],
#  [u'Tropidurus sertanejo.',
#   u'Lava lizards.',
#   u'Tropiduridae.',
#   u'Phylogeny.',
#   u'Caatinga reptiles.',
#   u'Bahia (Brazil : State)',
#   u'Brazil.',
#   u'South America.'],
#  [u'Haya griva.',
#   u'Ornithischia.',
#   u'Dinosaurs.',
#   u'Stratigraphic correlation.',
#   u'Paleontology, Stratigraphic.',
#   u'Ukhaa Tolgod Region (Mongolia)',
#   u'Mongolia.',
#   u'Gobi Desert (Mongolia and China)',
#   u'Geology, Stratigraphic.'],
#  [u'Svastra sabinensis sabinensis.',
#   u'Svastra.',
#   u'Nests.',
#   u'Larvae.',
#   u'Parasites.',
#   u'Cocoons.',
#   u'Triepeolus penicilliferus.',
#   u'Bees.',
#   u'Cochise County (Ariz.)',
#   u'Arizona.'],
#  [u'Chihuahuan spotted whiptail.',
#   u'Little striped whiptail.',
#   u'Aspidoscelis.',
#   u'Morphology.',
#   u'Variation.',
#   u'Hybridization.',
#   u'Teiidae.',
#   u'Lizards.',
#   u'Parthenogenesis in animals.'],
#  [u'"Barbus" validus.',
#   u'Barbs (Fish)',
#   u'Freshwater fishes.',
#   u'Congo River Valley.',
#   u'Congo (Democratic Republic)'],
#  []]

# %%
getMetadata(i)['subjects']
# Out:
# [u'Calciavis grandei.',
#  u'Lithornithidae.',
#  u'Ratites, Fossil.',
#  u'Ratites.',
#  u'Phylogeny.',
#  u'Fossil Butte National Monument (Wyo.)',
#  u'Green River Formation.',
#  u'Wyoming.']
